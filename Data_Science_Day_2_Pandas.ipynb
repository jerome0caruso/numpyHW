# %% [markdown]
# # Data Science Pandas

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Pandas</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Tabular Data Structures <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - from_dict() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - read_csv() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) <b>In-Class Exercise #1</b> <br>
#   &nbsp;&nbsp;&nbsp;&nbsp; d) Built-In Methods <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - head() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - tail() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - shape <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - describe() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - sort_values() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - keys() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - .columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Accessing Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Indexing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - df.loc <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - df.iloc <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Filtration <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Conditionals <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subsetting <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Column Transformations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Generating a New Column w/Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - User Defined Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Aggregations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Type of groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - mean() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() w/Multiple Columns <br>

# %% [markdown]
# ## Pandas <br>
#
# <p>Pandas is a flexible data analysis library built on top of NumPy that is excellent for working with tabular data. It is currently the de-facto standard for Python-based data analysis, and fluency in Pandas will do wonders for your productivity and frankly your resume. It is one of the fastest ways of getting from zero to answer in existence. </p>
#
# <ul>
#     <li>Pandas is a Python module, written in C. The Pandas module is a high performance, highly efficient, and high level data analysis library. It allows us to work with large sets of data called dataframes.</li>
#     <li>Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.)</li>
#     <li>Dataframe = Spreadsheet (has column headers, index, etc.)</li>
# </ul>

# %% [markdown]
# ### Importing

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import numpy as np
import pandas as pd

# always use pd, standard for data science

# %% [markdown]
# ### Tabular data structures <br>
# <p>The central object of study in Pandas is the DataFrame, which is a tabular data structure with rows and columns like an excel spreadsheet. The first point of discussion is the creation of dataframes both from native Python dictionaries, and text files through the Pandas I/O system.</p>

# %%
# !pip install faker
from faker import Faker
fake = Faker()
# Out:
# Requirement already satisfied: faker in c:\users\admin\anaconda3\lib\site-packages (9.7.1)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from faker) (2.8.1)
# Requirement already satisfied: text-unidecode==1.3 in c:\users\admin\anaconda3\lib\site-packages (from faker) (1.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
names = [fake.first_name() for i in range(10)]
ages = np.random.randint(18, 65, 10)

my_people = {
    'name': names,
    'age': ages
}
my_people
# Out:
# {'name': ['Jesse',
#   'Katie',
#   'Roger',
#   'Susan',
#   'Steven',
#   'Julia',
#   'Christopher',
#   'Carrie',
#   'John',
#   'Ashley'],
#  'age': array([37, 41, 37, 63, 23, 61, 38, 61, 64, 32])}

# %% [markdown]
# ##### from_dict()
#
# <p>Let's convert our not-so-useful-for-analysis dict into a Pandas dataframe. We can use the from_dict function to do this easily using Pandas:</p>

# %%
data = pd.DataFrame.from_dict(my_people)
data
# Out:
#           name  age
# 0        Jesse   37
# 1        Katie   41
# 2        Roger   37
# 3        Susan   63
# 4       Steven   23
# 5        Julia   61
# 6  Christopher   38
# 7       Carrie   61
# 8         John   64
# 9       Ashley   32

# %%
marathon = pd.read_csv('bm.csv', sep=',')
marathon
# Out:
#                           10K                     15K                    20K  \
# 0      12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 1      12/30/1899 12:30:27 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 2      12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:16 AM
# 3      12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:19 AM
# 4      12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# ...                       ...                     ...                    ...
# 26405   12/30/1899 1:35:41 AM   12/30/1899 2:23:35 AM  12/30/1899 3:12:44 AM
# 26406   12/30/1899 1:05:33 AM   12/30/1899 1:52:17 AM  12/30/1899 2:49:41 AM
# 26407   12/30/1899 1:43:36 AM   12/30/1899 2:32:36 AM                    NaN
# 26408   12/30/1899 1:27:19 AM   12/30/1899 2:17:17 AM  12/30/1899 3:11:40 AM
# 26409   12/30/1899 1:17:12 AM   12/30/1899 2:00:10 AM  12/30/1899 2:58:55 AM
#
#                          25K                    30K                    35K  \
# 0      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 1      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 2      12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:31 AM
# 3      12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:58 AM
# 4      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:41 AM
# ...                      ...                    ...                    ...
# 26405  12/30/1899 4:12:06 AM  12/30/1899 5:03:08 AM  12/30/1899 5:55:18 AM
# 26406  12/30/1899 3:50:19 AM  12/30/1899 4:50:01 AM  12/30/1899 5:53:48 AM
# 26407  12/30/1899 4:15:21 AM  12/30/1899 5:06:37 AM  12/30/1899 6:00:33 AM
# 26408  12/30/1899 4:06:10 AM  12/30/1899 5:07:09 AM  12/30/1899 6:06:07 AM
# 26409  12/30/1899 4:27:14 AM  12/30/1899 5:37:13 AM  12/30/1899 6:39:07 AM
#
#                          40K                      5K  Age      Bib  ...  \
# 0      12/30/1899 2:02:53 AM  12/30/1899 12:15:25 AM   24     11.0  ...
# 1      12/30/1899 2:03:14 AM  12/30/1899 12:15:24 AM   30     17.0  ...
# 2      12/30/1899 2:03:38 AM  12/30/1899 12:15:25 AM   25     23.0  ...
# 3      12/30/1899 2:04:35 AM  12/30/1899 12:15:25 AM   32     21.0  ...
# 4      12/30/1899 2:05:00 AM  12/30/1899 12:15:25 AM   31      9.0  ...
# ...                      ...                     ...  ...      ...  ...
# 26405  12/30/1899 6:46:57 AM  12/30/1899 12:46:44 AM   61  25166.0  ...
# 26406  12/30/1899 6:54:21 AM  12/30/1899 12:32:03 AM   25  25178.0  ...
# 26407  12/30/1899 6:54:38 AM  12/30/1899 12:53:11 AM   57  27086.0  ...
# 26408  12/30/1899 6:56:08 AM  12/30/1899 12:40:34 AM   64  25268.0  ...
# 26409  12/30/1899 7:41:23 AM  12/30/1899 12:39:36 AM   48  25266.0  ...
#
#        Division Gender                   Half  M/F                      Name  \
# 0             1      1  12/30/1899 1:04:35 AM    M           Kirui, Geoffrey
# 1             2      2  12/30/1899 1:04:35 AM    M               Rupp, Galen
# 2             3      3  12/30/1899 1:04:36 AM    M             Osako, Suguru
# 3             4      4  12/30/1899 1:04:45 AM    M          Biwott, Shadrack
# 4             5      5  12/30/1899 1:04:35 AM    M            Chebet, Wilson
# ...         ...    ...                    ...  ...                       ...
# 26405       344  11972  12/30/1899 3:23:31 AM    F  Steinbach, Paula Eyvonne
# 26406      4774  14436  12/30/1899 3:00:26 AM    M        Avelino, Andrew R.
# 26407       698  11973  12/30/1899 3:36:24 AM    F           Hantel, Johanna
# 26408      1043  14437  12/30/1899 3:22:30 AM    M              Reilly, Bill
# 26409      2553  14438  12/30/1899 3:08:16 AM    M             Rigsby, Scott
#
#       Number of Records          Official Time  Overall  \
# 0                     1  12/30/1899 2:09:37 AM        1
# 1                     1  12/30/1899 2:09:58 AM        2
# 2                     1  12/30/1899 2:10:28 AM        3
# 3                     1  12/30/1899 2:12:08 AM        4
# 4                     1  12/30/1899 2:12:35 AM        5
# ...                 ...                    ...      ...
# 26405                 1  12/30/1899 7:09:39 AM    26407
# 26406                 1  12/30/1899 7:16:59 AM    26408
# 26407                 1  12/30/1899 7:19:37 AM    26409
# 26408                 1  12/30/1899 7:20:44 AM    26410
# 26409                 1  12/30/1899 7:58:14 AM    26411
#
#                          Pace State
# 0      12/30/1899 12:04:57 AM   NaN
# 1      12/30/1899 12:04:58 AM    OR
# 2      12/30/1899 12:04:59 AM   NaN
# 3      12/30/1899 12:05:03 AM    CA
# 4      12/30/1899 12:05:04 AM   NaN
# ...                       ...   ...
# 26405  12/30/1899 12:16:24 AM    CA
# 26406  12/30/1899 12:16:40 AM    NC
# 26407  12/30/1899 12:16:47 AM    PA
# 26408  12/30/1899 12:16:49 AM    NY
# 26409  12/30/1899 12:18:15 AM    GA
#
# [26410 rows x 26 columns]

# %%
spotify = pd.read_csv('spot.csv')
spotify
# Out:
#                                   title         artist  \
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
#                     top genre  year  beats.per.minute  energy  danceability  \
# 0   canadian contemporary r&b  2020               171      73            51
# 1                         pop  2019                95      82            55
# 2                    cali rap  2021                91      72            70
# 3                         pop  2019               110      41            50
# 4                         pop  2017                95      45            60
# ..                        ...   ...               ...     ...           ...
# 95           canadian hip hop  2016               104      61            79
# 96                        pop  2015               120      79            75
# 97                  pop dance  2021               126      83            66
# 98                  dance pop  2018                93      80            61
# 99                  dance pop  2016               102      73            67
#
#     loudness.dB  liveness  valance  length  acousticness  speechiness  \
# 0            -6         9       33     200             0            6
# 1            -4        34       56     174            12            5
# 2            -4        32       73     141            17            4
# 3            -6        11       45     182            75            3
# 4            -6        11       17     263            16            2
# ..          ...       ...      ...     ...           ...          ...
# 95           -6        32       43     174             1            6
# 96           -7         9       88     235             6            3
# 97           -5        40       74     172             5           29
# 98           -5        16       50     185             7            4
# 99           -7         9       66     198             3           10
#
#     popularity
# 0           91
# 1           88
# 2           88
# 3           86
# 4           86
# ..         ...
# 95          66
# 96          66
# 97          66
# 98          56
# 99          53
#
# [100 rows x 14 columns]

# %% [markdown]
# ##### read_csv()
#
# <p>Pandas also provides a function to read a csv into a DataFrame. Let's take a look at this using the Marathon data from yesterday's class</p>

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ### In-Class Exercise #1 - Read in the Spotify CSV<br>
# <p>Use the pandas read_csv() method to read in the stats about the top 100 streamed songs on spotify.</p>

# %% [markdown]
# ### Built-In Methods <br>
#
# <p>These are methods that are frequently used when using Pandas to make your life easier. It is possible to spend a whole week simply exploring the built-in functions supported by DataFrames in Pandas. Here however, we will simply highlight a few ones that might be useful, to give you an idea of what's possible out of the box with Pandas:</p>

# %% [markdown]
# ##### head()

# %%
# DataFrame.head()  -- Accepts integer parameter(gives access to more rows)
spotify.head()
# Out:
#                     title         artist                  top genre  year  \
# 0         Blinding Lights     The Weeknd  canadian contemporary r&b  2020
# 1        Watermelon Sugar   Harry Styles                        pop  2019
# 2  Mood (feat. iann dior)       24kGoldn                   cali rap  2021
# 3       Someone You Loved  Lewis Capaldi                        pop  2019
# 4                 Perfect     Ed Sheeran                        pop  2017
#
#    beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 0               171      73            51           -6         9       33
# 1                95      82            55           -4        34       56
# 2                91      72            70           -4        32       73
# 3               110      41            50           -6        11       45
# 4                95      45            60           -6        11       17
#
#    length  acousticness  speechiness  popularity
# 0     200             0            6          91
# 1     174            12            5          88
# 2     141            17            4          88
# 3     182            75            3          86
# 4     263            16            2          86

# %% [markdown]
# ##### tail()

# %%
# DataFrame.tail()  -- Accepts integer parameter(gives access to more rows)
spotify.tail()
# Out:
#                                   title       artist         top genre  year  \
# 95                            One Dance        Drake  canadian hip hop  2016
# 96                                Sugar     Maroon 5               pop  2015
# 97                             Emotions   Mark Mendy         pop dance  2021
# 98                           Cold Water  Major Lazer         dance pop  2018
# 99  I Took A Pill In Ibiza - Seeb Remix  Mike Posner         dance pop  2016
#
#     beats.per.minute  energy  danceability  loudness.dB  liveness  valance  \
# 95               104      61            79           -6        32       43
# 96               120      79            75           -7         9       88
# 97               126      83            66           -5        40       74
# 98                93      80            61           -5        16       50
# 99               102      73            67           -7         9       66
#
#     length  acousticness  speechiness  popularity
# 95     174             1            6          66
# 96     235             6            3          66
# 97     172             5           29          66
# 98     185             7            4          56
# 99     198             3           10          53

# %% [markdown]
# ##### shape

# %%
# The dataframe has a shape property, just like a NumPy matrix. 
# print(df.shape) -- DataFrame.shape -- No Parameter rows by columns
print(spotify.shape)
# Out:
# (100, 14)

# %% [markdown]
# ##### keys()

# %%
# Access all of the keys/columns of the dataframe
# Dataframe.keys()
# gets panda index
print(spotify.keys())
# makes list
print(spotify.keys().tolist())
# Out:
# Index(['title', 'artist', 'top genre', 'year', 'beats.per.minute', 'energy',
#        'danceability', 'loudness.dB', 'liveness', 'valance', 'length',
#        'acousticness', 'speechiness', 'popularity'],
#       dtype='object')
# ['title', 'artist', 'top genre', 'year', 'beats.per.minute', 'energy', 'danceability', 'loudness.dB', 'liveness', 'valance', 'length', 'acousticness', 'speechiness', 'popularity']

# %% [markdown]
# ##### describe() <br>
# <p>Probably one of the most important methods to understand...</p>

# %%
# Collect summary statistics in one line
# DataFrame.describe() -- Accepts parameters (include, exclude)
spotify.describe()
# Out:
#               year  beats.per.minute      energy  danceability  loudness.dB  \
# count   100.000000        100.000000  100.000000     100.00000   100.000000
# mean   2015.960000        116.970000   62.680000      66.96000    -6.100000
# std       5.327497         27.470629   16.491737      13.60401     1.987334
# min    1975.000000         71.000000   11.000000      35.00000   -14.000000
# 25%    2015.000000         95.000000   52.000000      59.00000    -7.000000
# 50%    2017.000000        115.000000   64.500000      69.00000    -6.000000
# 75%    2018.000000        135.250000   76.000000      77.00000    -5.000000
# max    2021.000000        186.000000   92.000000      91.00000    -3.000000
#
#          liveness     valance      length  acousticness  speechiness  \
# count  100.000000  100.000000  100.000000     100.00000   100.000000
# mean    16.860000   49.970000  214.530000      24.95000     9.930000
# std     12.972403   21.737857   35.934974      26.27876     9.424077
# min      3.000000    6.000000  119.000000       0.00000     2.000000
# 25%     10.000000   33.750000  190.500000       4.00000     4.000000
# 50%     12.000000   48.000000  210.000000      13.00000     6.000000
# 75%     17.250000   66.000000  234.250000      41.50000    11.000000
# max     79.000000   93.000000  354.000000      98.00000    46.000000
#
#        popularity
# count  100.000000
# mean    79.670000
# std      5.905065
# min     53.000000
# 25%     79.000000
# 50%     81.000000
# 75%     83.000000
# max     91.000000

# %%
spotify.describe(include='all')
# Out:
#             title       artist  top genre         year  beats.per.minute  \
# count         100          100        100   100.000000        100.000000
# unique        100           64         34          NaN               NaN
# top     The Hills  Post Malone  dance pop          NaN               NaN
# freq            1            7         28          NaN               NaN
# mean          NaN          NaN        NaN  2015.960000        116.970000
# std           NaN          NaN        NaN     5.327497         27.470629
# min           NaN          NaN        NaN  1975.000000         71.000000
# 25%           NaN          NaN        NaN  2015.000000         95.000000
# 50%           NaN          NaN        NaN  2017.000000        115.000000
# 75%           NaN          NaN        NaN  2018.000000        135.250000
# max           NaN          NaN        NaN  2021.000000        186.000000
#
#             energy  danceability  loudness.dB    liveness     valance  \
# count   100.000000     100.00000   100.000000  100.000000  100.000000
# unique         NaN           NaN          NaN         NaN         NaN
# top            NaN           NaN          NaN         NaN         NaN
# freq           NaN           NaN          NaN         NaN         NaN
# mean     62.680000      66.96000    -6.100000   16.860000   49.970000
# std      16.491737      13.60401     1.987334   12.972403   21.737857
# min      11.000000      35.00000   -14.000000    3.000000    6.000000
# 25%      52.000000      59.00000    -7.000000   10.000000   33.750000
# 50%      64.500000      69.00000    -6.000000   12.000000   48.000000
# 75%      76.000000      77.00000    -5.000000   17.250000   66.000000
# max      92.000000      91.00000    -3.000000   79.000000   93.000000
#
#             length  acousticness  speechiness  popularity
# count   100.000000     100.00000   100.000000  100.000000
# unique         NaN           NaN          NaN         NaN
# top            NaN           NaN          NaN         NaN
# freq           NaN           NaN          NaN         NaN
# mean    214.530000      24.95000     9.930000   79.670000
# std      35.934974      26.27876     9.424077    5.905065
# min     119.000000       0.00000     2.000000   53.000000
# 25%     190.500000       4.00000     4.000000   79.000000
# 50%     210.000000      13.00000     6.000000   81.000000
# 75%     234.250000      41.50000    11.000000   83.000000
# max     354.000000      98.00000    46.000000   91.000000

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             100 non-null    object
#  1   artist            100 non-null    object
#  2   top genre         100 non-null    object
#  3   year              100 non-null    int64
#  4   beats.per.minute  100 non-null    int64
#  5   energy            100 non-null    int64
#  6   danceability      100 non-null    int64
#  7   loudness.dB       100 non-null    int64
#  8   liveness          100 non-null    int64
#  9   valance           100 non-null    int64
#  10  length            100 non-null    int64
#  11  acousticness      100 non-null    int64
#  12  speechiness       100 non-null    int64
#  13  popularity        100 non-null    int64
# dtypes: int64(11), object(3)
# memory usage: 11.1+ KB

# %% [markdown]
# ##### sort_values()

# %%
# Sort based on many labels, with left-to-right priority
# sorted_data = data.sort_values('ages').reset_index()
# DataFrame.sort_values('key')
sorted_ages = data.sort_values('age', ascending=False)
sorted_ages.reset_index(drop=True)
# Out:
#           name  age
# 0         John   64
# 1        Susan   63
# 2        Julia   61
# 3       Carrie   61
# 4        Katie   41
# 5  Christopher   38
# 6        Jesse   37
# 7        Roger   37
# 8       Ashley   32
# 9       Steven   23

# %% [markdown]
# ##### .columns

# %%
# will show all cols headers
# DataFrame.columns is an attribute
print(spotify.columns)
# Out:
# Index(['title', 'artist', 'top genre', 'year', 'beats.per.minute', 'energy',
#        'danceability', 'loudness.dB', 'liveness', 'valance', 'length',
#        'acousticness', 'speechiness', 'popularity'],
#       dtype='object')

# %% [markdown]
# ### Accessing Data

# %% [markdown]
# ##### Indexing
#
# <p>You can directly select a column of a dataframe just like you would a dict. The result is a Pandas 'Series' object.</p>

# %%
# Pandas DataFrame Object
print(type(spotify))
# Index a column from a dataframe
artist = spotify['artist']
print(artist)
# is now a series
print(type(artist))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0        The Weeknd
# 1      Harry Styles
# 2          24kGoldn
# 3     Lewis Capaldi
# 4        Ed Sheeran
#           ...
# 95            Drake
# 96         Maroon 5
# 97       Mark Mendy
# 98      Major Lazer
# 99      Mike Posner
# Name: artist, Length: 100, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# Index a series object
artist[5]
# Out:
# 'Imagine Dragons'

# %% [markdown]
# #### Accessing Multiple Columns

# %%
title_artist = spotify[['title', 'artist']]
title_artist
# Out:
#                                   title         artist
# 0                       Blinding Lights     The Weeknd
# 1                      Watermelon Sugar   Harry Styles
# 2                Mood (feat. iann dior)       24kGoldn
# 3                     Someone You Loved  Lewis Capaldi
# 4                               Perfect     Ed Sheeran
# ..                                  ...            ...
# 95                            One Dance          Drake
# 96                                Sugar       Maroon 5
# 97                             Emotions     Mark Mendy
# 98                           Cold Water    Major Lazer
# 99  I Took A Pill In Ibiza - Seeb Remix    Mike Posner
#
# [100 rows x 2 columns]

# %%
# Just made a smaller data_Frame = two series objects makes a dataframe
print(type(title_artist))
title_artist.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                     title         artist
# 0         Blinding Lights     The Weeknd
# 1        Watermelon Sugar   Harry Styles
# 2  Mood (feat. iann dior)       24kGoldn
# 3       Someone You Loved  Lewis Capaldi
# 4                 Perfect     Ed Sheeran

# %%
# slice
title_artist[10:20]
# Out:
#                            title            artist
# 10                        Closer  The Chainsmokers
# 11                       bad guy     Billie Eilish
# 12          Say You Won't Let Go      James Arthur
# 13                  Lucid Dreams        Juice WRLD
# 14                     All of Me       John Legend
# 15                       7 rings     Ariana Grande
# 16                Jocelyn Flores      XXXTENTACION
# 17                    goosebumps      Travis Scott
# 18                    Wake Me Up            Avicii
# 19  ROCKSTAR (feat. Roddy Ricch)            DaBaby

# %% [markdown]
# ##### df.loc

# %% [markdown]
# <p>Along the horizontal dimension, rows of Pandas DataFrames are Row objects. You will notice there is a third column present in the DataFrame - this is the $\textit{index}$. It is automatically generated as a row number, but can be reassigned to a column of your choice using the DataFrame.set_index(colname) method. We can use it to access particular Pandas $\textit{rows}$, which are also Series objects:</p>

# %%
# Grab the row of data from the dataframe with an assigned index label of 0 (so if rearranged not neces grabbing
# the 8th index but what was labled with 0 as the index as the start of creation)
print(data.loc[8])
# Out:
# name    John
# age       64
# Name: 8, dtype: object

# %%
print(data)
# access multiple rows with loc
print(data.loc[[0, 3, 5]])
# Out:
#           name  age
# 0        Jesse   37
# 1        Katie   41
# 2        Roger   37
# 3        Susan   63
# 4       Steven   23
# 5        Julia   61
# 6  Christopher   38
# 7       Carrie   61
# 8         John   64
# 9       Ashley   32
#     name  age
# 0  Jesse   37
# 3  Susan   63
# 5  Julia   61

# %%
print(data.loc[2:6])
# Out:
#           name  age
# 2        Roger   37
# 3        Susan   63
# 4       Steven   23
# 5        Julia   61
# 6  Christopher   38

# %%
print(sorted_ages)
# Out:
#           name  age
# 8         John   64
# 3        Susan   63
# 5        Julia   61
# 7       Carrie   61
# 1        Katie   41
# 6  Christopher   38
# 0        Jesse   37
# 2        Roger   37
# 9       Ashley   32
# 4       Steven   23

# %%
data.loc[np.arange(10) > 5]
# Out:
#           name  age
# 6  Christopher   38
# 7       Carrie   61
# 8         John   64
# 9       Ashley   32

# %%
# changes the index to the param given
new_index_df = data.set_index('name')
new_index_df
# Out:
#              age
# name
# Jesse         37
# Katie         41
# Roger         37
# Susan         63
# Steven        23
# Julia         61
# Christopher   38
# Carrie        61
# John          64
# Ashley        32

# %%
print(new_index_df.loc['Kayla'])
print(new_index_df.loc[['Sarah', 'Kayla']])
print(new_index_df.loc['Bernard':'Robert'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Kayla'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-c097b4feab52> in <module>
# ----> 1 print(new_index_df.loc['Kayla'])
#       2 print(new_index_df.loc[['Sarah', 'Kayla']])
#       3 print(new_index_df.loc['Bernard':'Robert'])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Kayla'

# %% [markdown]
# ##### df.iloc
# <p>df.iloc is purely integer-location based indexing for selection by position.</p>

# %%
# this is the current index of the array in the dataframe not the assinged value of index at the start
print(data.iloc[0])
print(sorted_ages.iloc[0])

# %%
print(data.iloc[2:6])

# %% [markdown]
# ### In-Class Exercise #2 - Most Upbeat Songs in Top 100 <br>
# <p>Return back a dataframe showing the Title, Artist, Year and Beats Per Minute for the 10 most upbeat songs (as determined by BPM)</p>

# %%
homework = spotify[['title', 'artist', 'year', 'beats.per.minute']]
completed_homework = homework.sort_values('beats.per.minute', ascending=False)
completed_homework = completed_homework.reset_index(drop=True)
completed_homework.head(10)

# %% [markdown]
# ### Filtration <br>
# <p>Let's look at how to filter dataframes for rows that fulfill a specific conditon.</p>

# %% [markdown]
# ##### Conditionals

# %%
data['age']

# %%
# turn into a boolean dataframe
data['age'] >= 40

# %% [markdown]
# ##### Subsetting

# %%
data[(data['age'] >= 40) & (data['name'] == 'Bernard')]
data[(data['age'] >= 40) | (data['age'] == 27)]
# Out:
#      name  age
# 1   Katie   41
# 3   Susan   63
# 5   Julia   61
# 7  Carrie   61
# 8    John   64

# %% [markdown]
# ### Column Transformations <br>
# <p>Rarely, if ever, will the columns in the original raw dataframe read from CSV or database table be the ones you actually need for your analysis. You will spend lots of time constantly transforming columns or groups of columns using general computational operations to produce new ones that are functions of the old ones. Pandas has full support for this: Consider the following fake dataframe containing member since year and the yearly dues for member:</p>

# %%
pay_options = {
    0: 100,
    1: 150,
    2: 200
}
membership = {
    'member_id': [np.random.randint(1000, 2000) for x in range(20)],
    'member_since': [np.random.randint(2000, 2021) for i in range(20)],
    'yearly_dues': [pay_options[np.random.randint(0,3)] for b in range(20)],
    'name': [fake.name() for n in range(20)]
}

customers = pd.DataFrame.from_dict(membership)
customers
# Out:
#     member_id  member_since  yearly_dues                name
# 0        1813          2015          150         Rose Nguyen
# 1        1875          2014          100       Bonnie Kelley
# 2        1618          2015          200      Rebekah Greene
# 3        1125          2011          200         Kevin White
# 4        1258          2005          200        Edward Jones
# 5        1090          2015          150      Jason Phillips
# 6        1860          2016          150      Patrick Torres
# 7        1565          2008          200          Mark Brown
# 8        1866          2013          200     Jenna Robertson
# 9        1405          2004          150        Stacey Jones
# 10       1841          2011          100      Kenneth Taylor
# 11       1141          2011          100     Joshua Mcdaniel
# 12       1355          2000          150     Katherine Miles
# 13       1615          2019          100   Mathew Richardson
# 14       1747          2009          150       Gregory Perry
# 15       1410          2002          200      Kathleen Gibbs
# 16       1181          2019          200  William Richardson
# 17       1072          2019          100       Joseph Powell
# 18       1893          2002          100         Amber Hayes
# 19       1010          2006          200        Amanda Young

# %%
from datetime import datetime
this_year = datetime.utcnow().year

# %% [markdown]
# ##### Generating a New Column w/Data

# %%
customers['customer_tenure'] = this_year - customers['member_since']

# %%
customers['active'] = True
customers
# Out:
#     member_id  member_since  yearly_dues                name  customer_tenure  \
# 0        1813          2015          150         Rose Nguyen                6
# 1        1875          2014          100       Bonnie Kelley                7
# 2        1618          2015          200      Rebekah Greene                6
# 3        1125          2011          200         Kevin White               10
# 4        1258          2005          200        Edward Jones               16
# 5        1090          2015          150      Jason Phillips                6
# 6        1860          2016          150      Patrick Torres                5
# 7        1565          2008          200          Mark Brown               13
# 8        1866          2013          200     Jenna Robertson                8
# 9        1405          2004          150        Stacey Jones               17
# 10       1841          2011          100      Kenneth Taylor               10
# 11       1141          2011          100     Joshua Mcdaniel               10
# 12       1355          2000          150     Katherine Miles               21
# 13       1615          2019          100   Mathew Richardson                2
# 14       1747          2009          150       Gregory Perry               12
# 15       1410          2002          200      Kathleen Gibbs               19
# 16       1181          2019          200  William Richardson                2
# 17       1072          2019          100       Joseph Powell                2
# 18       1893          2002          100         Amber Hayes               19
# 19       1010          2006          200        Amanda Young               15
#
#     active  total_paid loyalty_status
# 0     True         900         Silver
# 1     True         700         Silver
# 2     True        1200         Silver
# 3     True        2000         Silver
# 4     True        3200       Platinum
# 5     True         900         Silver
# 6     True         750         Brozne
# 7     True        2600           Gold
# 8     True        1600         Silver
# 9     True        2550       Platinum
# 10    True        1000         Silver
# 11    True        1000         Silver
# 12    True        3150       Platinum
# 13    True         200         Brozne
# 14    True        1800           Gold
# 15    True        3800       Platinum
# 16    True         400         Brozne
# 17    True         200         Brozne
# 18    True        1900       Platinum
# 19    True        3000           Gold

# %%
customers['total_paid'] = customers['yearly_dues'] * customers['customer_tenure']
customers
# Out:
#     member_id  member_since  yearly_dues                name  customer_tenure  \
# 0        1813          2015          150         Rose Nguyen                6
# 1        1875          2014          100       Bonnie Kelley                7
# 2        1618          2015          200      Rebekah Greene                6
# 3        1125          2011          200         Kevin White               10
# 4        1258          2005          200        Edward Jones               16
# 5        1090          2015          150      Jason Phillips                6
# 6        1860          2016          150      Patrick Torres                5
# 7        1565          2008          200          Mark Brown               13
# 8        1866          2013          200     Jenna Robertson                8
# 9        1405          2004          150        Stacey Jones               17
# 10       1841          2011          100      Kenneth Taylor               10
# 11       1141          2011          100     Joshua Mcdaniel               10
# 12       1355          2000          150     Katherine Miles               21
# 13       1615          2019          100   Mathew Richardson                2
# 14       1747          2009          150       Gregory Perry               12
# 15       1410          2002          200      Kathleen Gibbs               19
# 16       1181          2019          200  William Richardson                2
# 17       1072          2019          100       Joseph Powell                2
# 18       1893          2002          100         Amber Hayes               19
# 19       1010          2006          200        Amanda Young               15
#
#     active  total_paid
# 0     True         900
# 1     True         700
# 2     True        1200
# 3     True        2000
# 4     True        3200
# 5     True         900
# 6     True         750
# 7     True        2600
# 8     True        1600
# 9     True        2550
# 10    True        1000
# 11    True        1000
# 12    True        3150
# 13    True         200
# 14    True        1800
# 15    True        3800
# 16    True         400
# 17    True         200
# 18    True        1900
# 19    True        3000

# %% [markdown]
# ##### User Defined Function
#
# <p>If what you want to do to a column that can't be represented by simple mathematical operations, you can write your own $\textit{user defined function}$ with the full customizability available in Python and any external Python packages, then map it directly onto a column or row. Let's create a function that will return the loyalty status of a member based on their customer tenure. We will then apply that function to each row in our dataframe using the .apply() method:</p>

# %%
# axis = 0 is for columns and axis = 1 is for rows
def member(row):
    if row['customer_tenure'] > 15: 
        return 'Platinum'
    elif row['customer_tenure'] > 10:
        return 'Gold'
    elif row['customer_tenure'] > 5:
        return 'Silver'
    else: 
        return 'Brozne'
    print(row)

customers['loyalty_status'] = customers.apply(member, axis=1)
customers
# Out:
#     member_id  member_since  yearly_dues                name  customer_tenure  \
# 0        1813          2015          150         Rose Nguyen                6
# 1        1875          2014          100       Bonnie Kelley                7
# 2        1618          2015          200      Rebekah Greene                6
# 3        1125          2011          200         Kevin White               10
# 4        1258          2005          200        Edward Jones               16
# 5        1090          2015          150      Jason Phillips                6
# 6        1860          2016          150      Patrick Torres                5
# 7        1565          2008          200          Mark Brown               13
# 8        1866          2013          200     Jenna Robertson                8
# 9        1405          2004          150        Stacey Jones               17
# 10       1841          2011          100      Kenneth Taylor               10
# 11       1141          2011          100     Joshua Mcdaniel               10
# 12       1355          2000          150     Katherine Miles               21
# 13       1615          2019          100   Mathew Richardson                2
# 14       1747          2009          150       Gregory Perry               12
# 15       1410          2002          200      Kathleen Gibbs               19
# 16       1181          2019          200  William Richardson                2
# 17       1072          2019          100       Joseph Powell                2
# 18       1893          2002          100         Amber Hayes               19
# 19       1010          2006          200        Amanda Young               15
#
#     active  total_paid loyalty_status
# 0     True         900         Silver
# 1     True         700         Silver
# 2     True        1200         Silver
# 3     True        2000         Silver
# 4     True        3200       Platinum
# 5     True         900         Silver
# 6     True         750         Brozne
# 7     True        2600           Gold
# 8     True        1600         Silver
# 9     True        2550       Platinum
# 10    True        1000         Silver
# 11    True        1000         Silver
# 12    True        3150       Platinum
# 13    True         200         Brozne
# 14    True        1800           Gold
# 15    True        3800       Platinum
# 16    True         400         Brozne
# 17    True         200         Brozne
# 18    True        1900       Platinum
# 19    True        3000           Gold

# %% [markdown]
# ### In-Class Exercise #3 - Create Your Own UDF <br>
# <p>Using the Spotify data, create your own UDF which creates a new column called 'Banger' and puts every song with either an energy over 65 or danceability over 70 with a result of 'Yes' in the column if it is and 'No' if it is not.</p>

# %%
def isBanging(row):
    if row['energy'] > 65 or row['danceability'] > 70:
        return 'Yes'
    else:
        return 'No'

spotify['banger'] = spotify.apply(isBanging, axis=1)
spotify[['title', 'artist', 'banger']].head(10)
# Out:
#                     title           artist banger
# 0         Blinding Lights       The Weeknd    Yes
# 1        Watermelon Sugar     Harry Styles    Yes
# 2  Mood (feat. iann dior)         24kGoldn    Yes
# 3       Someone You Loved    Lewis Capaldi     No
# 4                 Perfect       Ed Sheeran     No
# 5                Believer  Imagine Dragons    Yes
# 6    lovely (with Khalid)    Billie Eilish     No
# 7                 Circles      Post Malone    Yes
# 8            Shape of You       Ed Sheeran    Yes
# 9                Memories         Maroon 5    Yes

# %%
spotify[4:10]

# %% [markdown]
# ### Aggregations <br>
# <p>The raw data plus some transformations is generally only half the story. Your objective is to extract actual insights and actionable conclusions from the data, and that means reducing it from potentially billions of rows to some summary statistics via aggregation functions.</p>

# %% [markdown]
# ##### groupby() <br>
# <p>The .groupby() function is in some ways a 'master' aggregation.</p>
#
# <p>Data tables will usually reserve one column as a primary key - that is, a column for which each row has a unique value. This is to facilitate access to the exact rows of a data table that a user wants to view. The other columns will often have repeated values, such as the age groups in the above examples. We can use these columns to explore the data using the Pandas API:</p>

# %%
customers.groupby('loyalty_status')
# retursn a dataframe must now add a method
# Out:
#                   member_id  member_since  yearly_dues  customer_tenure  \
# loyalty_status
# Brozne          1432.000000   2018.250000   137.500000         2.750000
# Gold            1440.666667   2007.666667   183.333333        13.333333
# Platinum        1464.200000   2002.600000   160.000000        18.400000
# Silver          1546.125000   2013.125000   150.000000         7.875000
#
#                 active   total_paid
# loyalty_status
# Brozne            True   387.500000
# Gold              True  2466.666667
# Platinum          True  2920.000000
# Silver            True  1162.500000

# %% [markdown]
# ##### Type of groupby()
#
# <p>The result is a new dataframe, the columns of which all contain the counts of the grouped field. Notice the type of a grouped dataframe:</p>

# %%
customers.groupby('loyalty_status').count()
# Out:
#                 member_id  member_since  yearly_dues  name  customer_tenure  \
# loyalty_status
# Brozne                  4             4            4     4                4
# Gold                    3             3            3     3                3
# Platinum                5             5            5     5                5
# Silver                  8             8            8     8                8
#
#                 active  total_paid
# loyalty_status
# Brozne               4           4
# Gold                 3           3
# Platinum             5           5
# Silver               8           8

# %% [markdown]
# <p>This is because simply grouping data doesn't quite make sense without an aggregation function like count() to pair with. In this case, we're counting occurances of the grouped field, but that's not all we can do. We can take averages, standard deviations, mins, maxes and much more! Let's see how this works a bit more:</p>

# %% [markdown]
# ##### mean()

# %%
# customers.groupby('loyalty_status').mean()[['yearly_dues', 'member_since']]
customers[['loyalty_status', 'yearly_dues', 'member_since']].groupby('loyalty_status').mean()
# Out:
#                 yearly_dues  member_since
# loyalty_status
# Brozne           137.500000   2018.250000
# Gold             183.333333   2007.666667
# Platinum         160.000000   2002.600000
# Silver           150.000000   2013.125000

# %% [markdown]
# ##### groupby() w/Multiple Columns
#
# <p>We end up with the average age of the groups in the last column, the average tenure in the tenure column, and so on and so forth. You can even split the groups more finely by passing a list of columns to group by:</p>

# %%
customers.groupby(['loyalty_status', 'yearly_dues']).mean()
# group all the bronze who pay x in yearly_dues
# Out:
#                               member_id  member_since  customer_tenure  \
# loyalty_status yearly_dues
# Brozne         100          1343.500000        2019.0              2.0
#                150          1860.000000        2016.0              5.0
#                200          1181.000000        2019.0              2.0
# Gold           150          1747.000000        2009.0             12.0
#                200          1287.500000        2007.0             14.0
# Platinum       100          1893.000000        2002.0             19.0
#                150          1380.000000        2002.0             19.0
#                200          1334.000000        2003.5             17.5
# Silver         100          1619.000000        2012.0              9.0
#                150          1451.500000        2015.0              6.0
#                200          1536.333333        2013.0              8.0
#
#                             active  total_paid
# loyalty_status yearly_dues
# Brozne         100            True       200.0
#                150            True       750.0
#                200            True       400.0
# Gold           150            True      1800.0
#                200            True      2800.0
# Platinum       100            True      1900.0
#                150            True      2850.0
#                200            True      3500.0
# Silver         100            True       900.0
#                150            True       900.0
#                200            True      1600.0

# %% [markdown]
# ### Homework Excersise #1 - White Sox Data<br>
# <p>Return a dataframe showing the White Sox qualified hitters* in order from best to worst XBHA**.</p>
# <p>*A hitter must have at least 100 At Bats (AB's) to qualify</p>
# <p>** XBHA is calculated as the number of extra base hits (2B, 3B, HR) divided by the number of At Bats (AB's)</p>

# %%
white_sox= pd.read_csv('ws.csv')
can = white_sox[(white_sox['AB'] >= 100)]

can = can.groupby(['Name'])[['2B', '3B', 'HR', 'AB']].sum()

def getTotal(row):
    total = 0
    
    total += row['2B']
    total += row['3B']
    total += row['HR']
    return total / row['AB']

can['total'] = can.apply(getTotal, axis=1)
sorted_players = can.sort_values('total', ascending=False).reset_index()
sorted_players
# Out:
#                Name  2B  3B  HR   AB     total
# 0       Luis Robert  22   1  13  275  0.130909
# 1        Adam Engel   9   0   7  123  0.130081
# 2      Gavin Sheets   8   0  11  160  0.118750
# 3   Yasmani Grandal   9   0  23  279  0.114695
# 4        José Abreu  30   2  30  566  0.109541
# 5    Billy Hamilton   8   3   2  127  0.102362
# 6      Eloy Jimenez  10   0  10  213  0.093897
# 7      Yoan Moncada  33   1  14  520  0.092308
# 8      Tim Anderson  29   2  17  527  0.091082
# 9     Andrew Vaughn  22   0  15  417  0.088729
# 10     Zack Collins  13   0   4  195  0.087179
# 11    Brian Goodwin  10   1   8  235  0.080851
# 12    Nick Madrigal  10   4   2  200  0.080000
# 13       Adam Eaton   8   2   5  189  0.079365
# 14     Leury Garcia  22   4   5  415  0.074699
# 15  Yermin Mercedes   9   1   7  240  0.070833
# 16        Jake Lamb   2   0   6  113  0.070796
# 17    Danny Mendick   5   0   2  164  0.042683
# 18  Cesar Hernandez   4   0   3  194  0.036082
